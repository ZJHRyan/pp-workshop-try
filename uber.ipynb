# %%
import pandas as pd

# %%
path='data/restaurants.csv'
df_data=pd.read_csv(path)
df=df_data.copy()
df
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 40222  40223        54     Mangia la pasta! (5610 N Interstate Hwy 35)    4.8
# 40223  40224        53                   Wholly Cow Burgers  (S Lamar)    4.6
# 40224  40225        52                                 EurAsia Ramen 3    4.7
# 40225  40226        51                        Austin's Habibi (5th St)    4.7
# 40226  40227        50                                     Beijing Wok    4.4
#
# ...

# %%
initial_data=df.dropna(axis=0,how='any')
initial_data=initial_data.replace(to_replace ="$", value =1)
initial_data=initial_data.replace(to_replace ="$$", value =2)
initial_data=initial_data.replace(to_replace ="$$$", value =3)
initial_data=initial_data.replace(to_replace ="$$$$", value =4)
initial_data
# Out:
#           id  position                                         name  score  \
# 6          7        27                                 Jinsei Sushi    4.7
# 13        14        51                 Panera (521 Fieldstown Road)    4.6
# 15        16        88     Jeni's Splendid Ice Cream (Pepper Place)    5.0
# 18        19        30                                 Falafel Cafe    4.9
# 19        20        40               MrBeast Burger (838 Odum Road)    3.7
# ...      ...       ...                                          ...    ...
# 40222  40223        54  Mangia la pasta! (5610 N Interstate Hwy 35)    4.8
# 40223  40224        53                Wholly Cow Burgers  (S Lamar)    4.6
# 40224  40225        52                              EurAsia Ramen 3    4.7
# 40225  40226        51                     Austin's Habibi (5th St)    4.7
# 40226  40227        50                                  Beijing Wok    4.4
#
#        ratings                                           category  \
# ...

# %%
initial_data.describe()
# Out:
#                  id      position         score       ratings   price_range  \
# count  19118.000000  19118.000000  19118.000000  19118.000000  19118.000000
# mean   20980.264044     70.211319      4.558437     77.769223      1.245266
# std    11218.930356     70.609928      0.296210     73.948624      0.445546
# min        7.000000      1.000000      1.300000     10.000000      1.000000
# 25%    12040.250000     13.000000      4.400000     26.000000      1.000000
# 50%    21008.000000     44.000000      4.600000     54.000000      1.000000
# 75%    30573.500000    109.000000      4.800000    102.000000      1.000000
# max    40227.000000    300.000000      5.000000    500.000000      4.000000
#
#                 lat           lng
# count  19118.000000  19118.000000
# mean      39.836742    -96.972796
# std        6.001526     18.556527
# min        0.000000   -123.011380
# 25%       36.914637   -119.176386
# 50%       38.931660    -96.701912
# 75%       45.616668    -77.460692
# ...

# %%
import matplotlib.pyplot as plt
initial_data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
plt.rcParams['figure.figsize']=(12.8, 7.2)
initial_data.plot(kind="scatter", x="lng", y="lat",alpha=0.01)
# Out:
# <AxesSubplot: xlabel='lng', ylabel='lat'>

# %%
plt.rcParams['figure.figsize']=(12.8, 7.2)
initial_data.plot(kind="scatter", x="lng", y="lat", alpha=0.4,
    s=initial_data["score"]/500, label="score",
    c="ratings", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
corr_matrix = initial_data.corr()
corr_matrix
# Out:
# /var/folders/zn/2h_jn9152knbzpbwpq843zr80000gn/T/ipykernel_46155/1982754373.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = initial_data.corr()
#                    id  position     score   ratings  price_range       lat  \
# id           1.000000  0.109013 -0.002191  0.068934    -0.001302 -0.675973
# position     0.109013  1.000000  0.101022  0.041163     0.075922 -0.002833
# score       -0.002191  0.101022  1.000000  0.176405    -0.050818  0.042613
# ratings      0.068934  0.041163  0.176405  1.000000     0.030494 -0.059380
# price_range -0.001302  0.075922 -0.050818  0.030494     1.000000  0.007661
# lat         -0.675973 -0.002833  0.042613 -0.059380     0.007661  1.000000
# lng          0.200055 -0.042116 -0.006513  0.081988    -0.020041 -0.606303
#
#                   lng
# ...

# %%
from pandas.plotting import scatter_matrix


attributes = ["position", "score", "ratings","price_range"]
scatter_matrix(initial_data[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot: xlabel='position', ylabel='position'>,
#         <AxesSubplot: xlabel='score', ylabel='position'>,
#         <AxesSubplot: xlabel='ratings', ylabel='position'>,
#         <AxesSubplot: xlabel='price_range', ylabel='position'>],
#        [<AxesSubplot: xlabel='position', ylabel='score'>,
#         <AxesSubplot: xlabel='score', ylabel='score'>,
#         <AxesSubplot: xlabel='ratings', ylabel='score'>,
#         <AxesSubplot: xlabel='price_range', ylabel='score'>],
#        [<AxesSubplot: xlabel='position', ylabel='ratings'>,
#         <AxesSubplot: xlabel='score', ylabel='ratings'>,
#         <AxesSubplot: xlabel='ratings', ylabel='ratings'>,
#         <AxesSubplot: xlabel='price_range', ylabel='ratings'>],
#        [<AxesSubplot: xlabel='position', ylabel='price_range'>,
#         <AxesSubplot: xlabel='score', ylabel='price_range'>,
#         <AxesSubplot: xlabel='ratings', ylabel='price_range'>,
# ...
